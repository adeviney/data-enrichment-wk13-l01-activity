# %% [markdown]
# ERD

# %% [markdown]
# ![png](Data/ERD.png)

# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

## Change username and password to match your personal MySQL Server settings
username = 'root' # default username for MySQL db is root
password = 'root' # whatever password you chose during MySQL installation.

connection = f'mysql+pymysql://{username}:{password}@localhost/Chinook'
engine = create_engine(connection)

# %%
q = """SHOW TABLES;"""
pd.read_sql(q,engine)
# Out:
#    Tables_in_chinook
# 0              album
# 1             artist
# 2           customer
# 3           employee
# 4              genre
# 5            invoice
# 6        invoiceline
# 7          mediatype
# 8           playlist
# 9      playlisttrack
# 10             track

# %% [markdown]
# # Queries
#
# 1. What is the most a customer has spent on a single purchase and what is their customerId?
# 2. What country is the customer with the largest total bill from (from question 2)?
# 3. Which customerID made the fewest purchases (invoices)?
# 4. Retrieve the id, name, and # of playlists for  tracks that appear on playlists more than 4 times?

# %% [markdown]
# ## What is the most a customer has spent on a single purchase and what is their customerId?

# %%
q = """
SELECT CustomerId, Total
FROM invoice
ORDER BY Total DESC
LIMIT 1;
"""
pd.read_sql(q,engine)
# Out:
#    CustomerId  Total
# 0           6  25.86

# %% [markdown]
# ## What country is the customer with the largest total bill from (from question 2)?

# %%
q = """
SELECT i.CustomerId, i.Total, c.Country
FROM invoice i JOIN customer c ON i.CustomerId = c.CustomerId
ORDER BY Total DESC
LIMIT 1
"""
pd.read_sql(q,engine)
# Out:
#    CustomerId  Total         Country
# 0           6  25.86  Czech Republic

# %% [markdown]
# ## Which customerID made the fewest purchases (invoices)?

# %%
q = """
SELECT i.CustomerId, COUNT(*) as num_purchases
FROM invoice i
GROUP BY CustomerId
ORDER BY num_purchases 
LIMIT 1;
"""
pd.read_sql(q,engine)
# Out:
#    CustomerId  num_purchases
# 0          59              6

# %% [markdown]
# ## Retrieve the id, name, and # of playlists for  tracks that appear on playlists more than 4 times?

# %%
q = """

SELECT t.TrackId, t.Name, COUNT(*) as num_playlists_per_track
FROM track t JOIN playlisttrack pt ON pt.TrackId = t.TrackId
JOIN playlist p ON p.PlaylistId = pt.PlaylistId 
GROUP BY pt.TrackId
HAVING num_playlists_per_track > 4
ORDER BY num_playlists_per_track DESC
"""
pd.read_sql(q,engine)
# Out:
#     TrackId                                               Name  \
# 0      3403                             Intoitus: Adorate Deum
# 1      3404                                 Miserere mei, Deus
# 2      3408  Aria Mit 30 Veränderungen, BWV 988 "Goldberg V...
# 3      3409  Suite for Solo Cello No. 1 in G Major, BWV 100...
# 4      3410  The Messiah: Behold, I Tell You a Mystery... T...
# 5      3411  Solomon HWV 67: The Arrival of the Queen of Sheba
# 6      3415      Symphony No.5 in C Minor: I. Allegro con brio
# 7      3416                                          Ave Maria
# 8      3417   Nabucco: Chorus, "Va, Pensiero, Sull'ali Dorate"
# 9      3418             Die Walküre: The Ride of the Valkyries
# 10     3421  Nimrod (Adagio) from Variations On an Original...
# 11     3423                    Jupiter, the Bringer of Jollity
# 12     3424                   Turandot, Act III, Nessun dorma!
# 13     3426                          Carmina Burana: O Fortuna
# 14     3430  Toccata and Fugue in D Minor, BWV 565: I. Toccata
# 15     3432  Scheherazade, Op. 35: I. The Sea and Sindbad's...
# 16     3434  Concerto for Piano No. 2 in F Minor, Op. 21: I...
# 17     3435    Cavalleria Rusticana  Act  Intermezzo Sinfonico
# 18     3436  Karelia Suite, Op.11: 2. Ballade (Tempo Di Men...
# 19     3437  Piano Sonata No. 14 in C Sharp Minor, Op. 27, ...
# 20     3438                           Fantasia On Greensleeves
# 21     3439              Das Lied Von Der Erde, Von Der Jugend
# 22     3442  Wellington's Victory or the Battle Symphony, O...
# 23     3444   Romeo et Juliette: No. 11 - Danse des Chevaliers
# 24     3445                       On the Beautiful Blue Danube
# 25     3446  Symphonie Fantastique, Op. 14: V. Songe d'une ...
# 26     3447                                   Carmen: Overture
# 27     3448  Lamentations of Jeremiah, First Set  Incipit L...
# 28     3449  Music for the Royal Fireworks, HWV351 (1749): ...
# 29     3451  Die Zauberflöte, K.620: "Der Hölle Rache Kocht...
# 30     3454  Symphony No. 41 in C Major, K. 551, "Jupiter":...
# 31     3481  A Midsummer Night's Dream, Op.61 Incidental Mu...
# 32     3482    Suite No. 3 in D, BWV 1068: III. Gavotte I & II
# 33     3485  Symphony No. 3 Op. 36 for Orchestra and Sopran...
# 34     3489                Symphony No. 2: III. Allegro vivace
# 35     3490          Partita in E Major, BWV 1006A: I. Prelude
# 36     3492                                      Sing Joyfully
# 37     3493                           Metopes, Op. 29: Calypso
# 38     3498  Concerto for Violin, Strings and Continuo in G...
# 39     3499  Pini Di Roma (Pinien Von Rom)  I Pini Della Vi...
# 40     3503                                      Koyaanisqatsi
#
#     num_playlists_per_track
# 0                         5
# 1                         5
# 2                         5
# 3                         5
# 4                         5
# 5                         5
# 6                         5
# 7                         5
# 8                         5
# 9                         5
# 10                        5
# 11                        5
# 12                        5
# 13                        5
# 14                        5
# 15                        5
# 16                        5
# 17                        5
# 18                        5
# 19                        5
# 20                        5
# 21                        5
# 22                        5
# 23                        5
# 24                        5
# 25                        5
# 26                        5
# 27                        5
# 28                        5
# 29                        5
# 30                        5
# 31                        5
# 32                        5
# 33                        5
# 34                        5
# 35                        5
# 36                        5
# 37                        5
# 38                        5
# 39                        5
# 40                        5
